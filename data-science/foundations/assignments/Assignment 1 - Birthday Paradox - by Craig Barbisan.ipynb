# %% [markdown]
# ## Assignment 1 - Intro to Python

# %% [markdown]
# ## Medium complexity - Birthday Paradox

# %% [markdown]
# Birthday paradox concerns the probability that, in a set of n randomly chosen people, some pair of them will have the same birthday. You can read about this problem at https://en.wikipedia.org/wiki/Birthday_problem.
#
# Write a function called <i><b>has_duplicates</b></i>, that takes a list and returns <i>True</i> if there is any element that appears more than once. It should not modify the original list.
#
# If there are 45 students in the class, what are the chances that two of you have the same birthday? You can estimate this probability by generating random samples of 45 birthdays and checking for matches.
#
# <i>Hints:</i><br>
# (1) you can generate random birthdays with the <i>randint</i> function in the random module.<br>
# (2) For simplicity, use the day number of the year, not the actual date, <br>
# (3) you can use the book solution as a starting point for this assignment: https://github.com/AllenDowney/ThinkPython2/blob/master/code/birthday.py.
# <br>
# <br>
# The code should print out:
# <li>number of students,</li>
# <li>number of iterations/samples</li>
# <li>list of duplicate days for each iteration, where duplicates are found.</li>
# <li>probability</li>

# %%
"""This module contains a code example related to Think Python, 2nd Edition by Allen Downey
http://thinkpython2.com
Copyright 2015 Allen Downey
License: http://creativecommons.org/licenses/by/4.0/

Revised by Craig Barbisan per the requirements of Assignment 1, Option 2
Book solution code that was not used, was removed
Foundations of Data Science, SCS_3250_005
University of Toronto
October 2017
"""

import random

# Added by Craig
def get_duplicates(t):
    """ Returns a list of duplicate values in the input list
    
    t: list
    returns: list of int
    """
    
    # Duplicate values will be stored as keys in a dictionary for efficient access.
    # A count of occurrences of the duplicate will be stored as the value, although
    # this is not actually used by the solution.
    dups = dict()
    
    # For each element of the list, count the occurences of that element.
    # If it occurs more than once, add it as a key to the dups dictionary.
    # For efficiency, we only count occurrences if the element is not already in
    # the dups dictionary. This means we are invoking the count() method for at
    # most, once per unique value in the list.
    for element in t:
        
        if element not in dups:
            count = t.count(element)
            if count > 1:
                dups[element] = count
            
    # Return the keys of the dups dictionary, cast as a list
    return list(dups.keys())

# unchanged
def random_bdays(n):
    """Returns a list of integers between 1 and 365, with length n.
    n: int
    returns: list of int
    """
    t = []
    for i in range(n):
        bday = random.randint(1, 365)
        t.append(bday)
    return t


# Modified by Craig - was previously count_matches() function
def get_matches(num_students, num_simulations):
    """Generates a sample of birthdays and records matches.
    All matches in each iteration are stored in a list.
    Each list is added to a dictionary as a value, indexed by its iteration number.
    
    num_students: how many students in the group
    num_samples: how many groups to simulate
    
    returns: dictionary of lists
    """
    
    matches = dict()
    
    # Iterates the number of times specified by the num_simulations argument.
    # This body of this loop creates a group, generates a list of duplicates
    # in the group, and adds that list to the matches dictionary if it is not
    # empty
    for i in range(num_simulations):
        group = random_bdays(num_students)
        dups = get_duplicates(group)
        if len(dups) > 0:
            matches[i] = dups
            
    return matches


# Modified by Craig
def main():
    """Runs the birthday simulation and prints the number of matches, the matches within each group,
    and the probability of some pair in the group sharing a birthday, given the size of the group.
    """
    num_students = 45
    
    # Based on my research, our probability when the number of students per group is 45, should
    # be approximately 0.94. Through trial and error, the smallest sample size I could find that
    # consistently returned 0.94 is 4500. So I have selected 4500 as my sample size.
    num_simulations = 4500
    
    m = get_matches(num_students, num_simulations)

    print('# of simulations = {:d}'.format(num_simulations))
    print('# of students per group = {:d}'.format(num_students))
    print('# of groups with matches = {:d}\n'.format(len(m)))
    print('Probability that, in a set of {:d} randomly chosen students, some pair of them will have the same birthday = {:.2f}\n'.format(num_students, len(m)/num_simulations))
    
    for i in m:
        iter_num = i + 1
        print('Matches in iteration {:d}: {}'.format(iter_num, m[i]))

# If this module is being run as the main program
# (i.e. it has not been imported for use by some other module)
# then execute the main() function, which will be our entry
# point to the program.
if __name__ == '__main__':
    main()
# Out:
# # of simulations = 4500
# # of students per group = 45
# # of groups with matches = 4240
#
# Probability that, in a set of 45 randomly chosen students, some pair of them will have the same birthday = 0.94
#
# Matches in iteration 1: [164, 58]
# Matches in iteration 2: [179, 288, 62, 74]
# Matches in iteration 3: [269, 317]
# Matches in iteration 4: [293, 125]
# Matches in iteration 5: [74]
# Matches in iteration 6: [303, 104, 2]
# Matches in iteration 7: [4, 56, 163]
# Matches in iteration 8: [185, 143]
# Matches in iteration 9: [227, 225, 48, 230]
# Matches in iteration 10: [357, 309]
# Matches in iteration 11: [291, 237]
# Matches in iteration 12: [292, 106, 201, 60, 139]
# Matches in iteration 13: [209, 45, 177]
# Matches in iteration 14: [57, 40, 219]
# Matches in iteration 15: [253, 187, 273]
# Matches in iteration 16: [359]
# Matches in iteration 17: [71]
# Matches in iteration 18: [351, 144]
# Matches in iteration 19: [197]
# Matches in iteration 20: [326, 348]
# Matches in iteration 21: [263]
# Matches in iteration 23: [142, 13, 217, 204]
# Matches in iteration 24: [252]
# Matches in iteration 25: [349, 267, 325, 29, 25]
# Matches in iteration 26: [23, 265, 122, 39, 290]
# Matches in iteration 27: [21, 328, 339]
# Matches in iteration 28: [83]
# Matches in iteration 29: [32, 30, 45]
# Matches in iteration 30: [313, 293, 68]
# Matches in iteration 31: [225]
# Matches in iteration 32: [45, 64, 306]
# Matches in iteration 33: [182, 58, 239, 330, 39]
# Matches in iteration 34: [92, 296]
# Matches in iteration 35: [194, 271]
# Matches in iteration 37: [125, 86]
# Matches in iteration 38: [126, 360, 316, 189, 160, 109]
# Matches in iteration 39: [143, 62]
# Matches in iteration 40: [180, 272, 333]
# Matches in iteration 42: [352, 278, 353, 152]
# Matches in iteration 43: [324, 212, 224, 275]
# Matches in iteration 44: [28]
# Matches in iteration 45: [124, 266, 309]
# Matches in iteration 46: [31, 66, 126]
# Matches in iteration 48: [12, 267, 162]
# Matches in iteration 49: [16, 49]
# Matches in iteration 50: [284]
# Matches in iteration 51: [89, 185]
# Matches in iteration 52: [155, 23, 149]
# Matches in iteration 53: [302]
# Matches in iteration 54: [345, 290]
# Matches in iteration 55: [39, 243, 337]
# Matches in iteration 56: [174, 129, 332, 3]
# Matches in iteration 57: [307]
# Matches in iteration 59: [256, 21, 16]
# Matches in iteration 60: [355]
# Matches in iteration 61: [286, 218, 241]
# Matches in iteration 62: [48, 196, 46]
# Matches in iteration 64: [287, 170, 227]
# Matches in iteration 65: [164, 255]
# Matches in iteration 66: [60]
# Matches in iteration 67: [346]
# Matches in iteration 69: [336, 252]
# Matches in iteration 70: [317]
# Matches in iteration 71: [51, 277]
# Matches in iteration 72: [75, 272]
# Matches in iteration 73: [364]
# Matches in iteration 74: [32, 148, 56]
# Matches in iteration 75: [244]
# Matches in iteration 76: [25, 215, 44]
# Matches in iteration 77: [333, 139, 99]
# Matches in iteration 78: [80, 291]
# Matches in iteration 79: [43, 73]
# Matches in iteration 80: [21, 151, 267, 281, 176]
# Matches in iteration 81: [164, 332, 216]
# Matches in iteration 82: [51]
# Matches in iteration 83: [231]
# Matches in iteration 84: [41, 313]
# Matches in iteration 85: [286, 239]
# Matches in iteration 86: [114, 23, 148, 209]
# Matches in iteration 87: [231, 124, 332]
# Matches in iteration 88: [202, 255, 293]
# Matches in iteration 89: [329, 277]
# Matches in iteration 90: [360, 80, 154, 219]
# Matches in iteration 91: [150, 279]
# Matches in iteration 92: [319, 164, 193, 67]
# Matches in iteration 93: [118, 44, 334]
# Matches in iteration 95: [56, 279]
# Matches in iteration 96: [134, 327]
# Matches in iteration 97: [27, 189, 28, 126]
# Matches in iteration 98: [98, 349, 355, 96, 263]
# Matches in iteration 99: [100, 315, 162]
# Matches in iteration 100: [326, 129]
# Matches in iteration 101: [257, 72]
# Matches in iteration 102: [276, 362, 126]
# Matches in iteration 103: [300, 154]
# Matches in iteration 104: [146, 53, 266, 256, 329, 153]
# Matches in iteration 105: [21, 279]
# Matches in iteration 106: [279, 188, 325]
# Matches in iteration 107: [264, 134]
# Matches in iteration 108: [300, 210]
# Matches in iteration 109: [173, 50]
# Matches in iteration 110: [111, 144, 308]
# Matches in iteration 111: [339, 101]
# Matches in iteration 112: [70, 272, 198]
# Matches in iteration 113: [353, 245]
# Matches in iteration 114: [330]
# Matches in iteration 115: [61]
# Matches in iteration 116: [276]
# Matches in iteration 117: [332, 325, 174, 287]
# Matches in iteration 118: [78, 28, 38]
# Matches in iteration 119: [83, 226]
# Matches in iteration 120: [102, 327]
# Matches in iteration 121: [18, 111]
# Matches in iteration 122: [57, 161, 73]
# Matches in iteration 123: [2, 130, 155, 204]
# Matches in iteration 124: [167, 290]
# Matches in iteration 125: [271, 276, 127]
# Matches in iteration 126: [294, 327]
# Matches in iteration 127: [330, 281, 179]
# Matches in iteration 128: [125, 203, 343]
# Matches in iteration 129: [253, 220, 69]
# Matches in iteration 130: [302]
# Matches in iteration 131: [77, 290]
# Matches in iteration 133: [116, 272]
# Matches in iteration 134: [149, 362]
# Matches in iteration 135: [111]
# Matches in iteration 136: [38, 53, 233, 106]
# Matches in iteration 137: [203, 242, 251]
# Matches in iteration 138: [53, 164]
# Matches in iteration 139: [33, 219]
# Matches in iteration 140: [31, 68, 236]
# Matches in iteration 141: [48, 150, 132, 175]
# Matches in iteration 142: [232, 144, 347, 296, 209, 177]
# Matches in iteration 143: [105, 119, 334, 282, 145, 356]
# Matches in iteration 144: [63]
# Matches in iteration 145: [260, 263, 33]
# Matches in iteration 146: [357]
# Matches in iteration 147: [258, 296]
# Matches in iteration 148: [238]
# Matches in iteration 149: [362, 218, 78]
# Matches in iteration 150: [197, 251, 152, 124]
# Matches in iteration 151: [327, 342, 175]
# Matches in iteration 152: [355, 17, 48, 192]
# Matches in iteration 153: [65, 146, 102, 84, 156, 106]
# Matches in iteration 154: [284, 32]
# Matches in iteration 155: [321, 284]
# Matches in iteration 156: [158]
# Matches in iteration 157: [224, 282, 186]
# Matches in iteration 158: [288, 1, 248]
# Matches in iteration 159: [146, 239]
# Matches in iteration 161: [40, 17, 190, 13]
# Matches in iteration 162: [116, 307, 105]
# Matches in iteration 163: [163]
# Matches in iteration 164: [110, 246]
# Matches in iteration 165: [176, 56, 51, 71]
# Matches in iteration 166: [110, 337, 119]
# Matches in iteration 167: [361, 146, 9]
# Matches in iteration 168: [251, 199]
# Matches in iteration 169: [246, 311]
# Matches in iteration 170: [325]
# Matches in iteration 171: [164, 61]
# Matches in iteration 172: [71, 113, 20]
# Matches in iteration 174: [263]
# Matches in iteration 175: [264]
# Matches in iteration 176: [226, 318]
# Matches in iteration 177: [10, 126, 346, 101, 244, 215, 137, 163]
# Matches in iteration 178: [282, 96, 138, 61, 170]
# Matches in iteration 179: [278]
# Matches in iteration 180: [280, 272, 1, 82, 274]
# Matches in iteration 181: [10, 362, 342, 299]
# Matches in iteration 182: [178]
# Matches in iteration 184: [148, 118, 153, 261, 179, 238, 362, 94, 255]
# Matches in iteration 185: [221]
# Matches in iteration 186: [12, 72, 104]
# Matches in iteration 187: [129, 282, 179]
# Matches in iteration 188: [228]
# Matches in iteration 189: [40, 356, 4]
# Matches in iteration 190: [294, 271, 51]
# Matches in iteration 191: [123, 364]
# Matches in iteration 192: [149, 273, 235, 64]
# Matches in iteration 193: [354]
# Matches in iteration 194: [129, 288]
# Matches in iteration 195: [6, 187, 64, 89]
# Matches in iteration 196: [326, 14]
# Matches in iteration 197: [24, 109, 56, 122, 309, 135]
# Matches in iteration 198: [244, 330, 145]
# Matches in iteration 199: [131, 248, 254, 67]
# Matches in iteration 200: [110, 4, 188, 249]
# Matches in iteration 201: [342, 58]
# Matches in iteration 202: [133, 353]
# Matches in iteration 203: [320]
# Matches in iteration 204: [219, 271]
# Matches in iteration 205: [196, 348, 188]
# Matches in iteration 206: [214, 234, 361]
# Matches in iteration 207: [181, 162, 87]
# Matches in iteration 208: [255, 39]
# Matches in iteration 209: [27]
# Matches in iteration 210: [264, 149]
# Matches in iteration 211: [263]
# Matches in iteration 212: [206, 331, 61, 259]
# Matches in iteration 213: [209, 249]
# Matches in iteration 214: [127, 340]
# Matches in iteration 215: [41]
# Matches in iteration 216: [20]
# Matches in iteration 217: [261, 61, 25]
# Matches in iteration 218: [109, 151]
# Matches in iteration 219: [27]
# Matches in iteration 220: [253, 104]
# Matches in iteration 221: [229, 301, 270]
# Matches in iteration 222: [231, 70, 137]
# Matches in iteration 223: [71, 278, 32, 17, 338]
# Matches in iteration 224: [117, 47, 63]
# Matches in iteration 225: [86, 58, 252]
# Matches in iteration 226: [44, 278, 49, 30, 303]
# Matches in iteration 227: [108]
# Matches in iteration 228: [302, 291, 56, 12, 283]
# Matches in iteration 229: [333]
# Matches in iteration 230: [7, 246, 39, 132]
# Matches in iteration 231: [356]
# Matches in iteration 232: [117]
# Matches in iteration 233: [278, 40]
# Matches in iteration 234: [145, 169, 198, 231]
# Matches in iteration 235: [84, 208, 225]
# Matches in iteration 236: [336, 164, 123, 13]
# Matches in iteration 237: [208, 135, 297]
# Matches in iteration 238: [115, 118]
# Matches in iteration 239: [283, 252, 291, 253, 249]
# Matches in iteration 240: [123, 161]
# Matches in iteration 241: [46, 128, 149]
# Matches in iteration 242: [220, 321]
# Matches in iteration 244: [309, 190]
# Matches in iteration 245: [190, 35]
# Matches in iteration 246: [181]
# Matches in iteration 247: [246, 272]
# Matches in iteration 248: [124, 83, 196]
# Matches in iteration 249: [279, 75, 10, 360]
# Matches in iteration 250: [283]
# Matches in iteration 251: [334, 274, 23, 228]
# Matches in iteration 252: [182, 84, 315]
# Matches in iteration 253: [355, 335, 207]
# Matches in iteration 254: [122]
# Matches in iteration 255: [264, 292]
# Matches in iteration 256: [66]
# Matches in iteration 257: [80, 206, 83]
# Matches in iteration 258: [48, 258, 69]
# Matches in iteration 259: [184, 263, 121]
# Matches in iteration 260: [21, 347, 182, 176]
# Matches in iteration 261: [332]
# Matches in iteration 262: [123, 170]
# Matches in iteration 264: [20, 79, 335, 359, 123]
# Matches in iteration 265: [149, 278, 273, 248, 49]
# Matches in iteration 266: [40, 258, 28]
# Matches in iteration 267: [217, 323]
# Matches in iteration 268: [41, 319, 230, 7]
# Matches in iteration 269: [65, 251, 85, 246]
# Matches in iteration 270: [302, 102]
# Matches in iteration 271: [80, 177, 218]
# Matches in iteration 272: [3]
# Matches in iteration 273: [184, 43, 221, 107]
# Matches in iteration 274: [238, 33]
# Matches in iteration 275: [70, 262, 105, 111, 85, 266]
# Matches in iteration 276: [364, 88, 82, 152]
# Matches in iteration 277: [23, 144, 187]
# Matches in iteration 278: [194, 233, 245]
# Matches in iteration 279: [164, 215]
# Matches in iteration 280: [156, 43]
# Matches in iteration 281: [77, 48]
# Matches in iteration 283: [152, 126]
# Matches in iteration 284: [341, 22, 307, 23]
# Matches in iteration 285: [73]
# Matches in iteration 286: [328, 175, 69]
# Matches in iteration 287: [197]
# Matches in iteration 288: [314]
# Matches in iteration 289: [324, 35]
# Matches in iteration 290: [307, 350]
# Matches in iteration 291: [136, 186]
# Matches in iteration 292: [178, 142, 192, 40, 353]
# Matches in iteration 293: [190, 351, 191, 52]
# Matches in iteration 294: [245, 343, 193, 354]
# Matches in iteration 295: [264, 324, 211, 173]
# Matches in iteration 296: [125, 250]
# Matches in iteration 297: [260]
# Matches in iteration 298: [128, 341]
# Matches in iteration 299: [236, 319, 219]
# Matches in iteration 300: [150, 167, 31]
# Matches in iteration 301: [293, 59]
# Matches in iteration 302: [41, 235, 134, 298, 26]
# Matches in iteration 303: [346, 308, 356, 157, 169]
# Matches in iteration 304: [354, 188, 173]
# Matches in iteration 305: [196, 94, 58]
# Matches in iteration 307: [55, 193]
# Matches in iteration 308: [122, 37, 275]
# Matches in iteration 309: [155]
# Matches in iteration 310: [100, 204]
# Matches in iteration 311: [182, 341]
# Matches in iteration 312: [27, 215, 239]
# Matches in iteration 313: [340, 47, 192]
# Matches in iteration 314: [333, 120, 138, 359, 258]
# Matches in iteration 315: [165, 92]
# Matches in iteration 317: [92, 218]
# Matches in iteration 318: [135, 112, 273]
# Matches in iteration 319: [102, 100, 107, 40, 272]
# Matches in iteration 320: [304, 49, 50]
# Matches in iteration 321: [133, 358, 342, 192, 251]
# Matches in iteration 322: [295, 231, 127]
# Matches in iteration 323: [208, 324, 67, 158, 127]
# Matches in iteration 324: [134, 202, 125]
# Matches in iteration 325: [247]
# Matches in iteration 326: [187, 25]
# Matches in iteration 327: [351]
# Matches in iteration 328: [18]
# Matches in iteration 330: [365]
# Matches in iteration 331: [204, 273, 20, 186]
# Matches in iteration 332: [263, 129]
# Matches in iteration 333: [344]
# Matches in iteration 334: [138, 325]
# Matches in iteration 335: [118, 248]
# Matches in iteration 336: [330, 325, 179, 359]
# Matches in iteration 337: [119, 257]
# Matches in iteration 339: [37, 176, 35, 47, 38]
# Matches in iteration 340: [122, 339, 228, 49, 5, 347]
# Matches in iteration 341: [324]
# Matches in iteration 342: [41, 43]
# Matches in iteration 344: [51]
# Matches in iteration 345: [59]
# Matches in iteration 346: [299, 142, 16, 207, 244]
# Matches in iteration 347: [17, 147]
# Matches in iteration 348: [171, 249, 185]
# Matches in iteration 349: [120, 365, 75]
# Matches in iteration 350: [245]
# Matches in iteration 351: [136, 108, 190]
# Matches in iteration 352: [334, 55]
# Matches in iteration 353: [118, 109, 124, 319]
# Matches in iteration 354: [112, 47]
# Matches in iteration 355: [177, 47]
# Matches in iteration 356: [201, 225, 146, 353]
# Matches in iteration 357: [152, 139, 216]
# Matches in iteration 358: [181, 134]
# Matches in iteration 359: [116, 17, 127]
# Matches in iteration 360: [156]
# Matches in iteration 361: [97, 300, 207, 45]
# Matches in iteration 362: [349, 107]
# Matches in iteration 363: [222, 70]
# Matches in iteration 364: [356, 258]
# Matches in iteration 365: [278]
# Matches in iteration 366: [317]
# Matches in iteration 367: [121, 112]
# Matches in iteration 368: [121, 312, 63]
# Matches in iteration 369: [284, 128]
# Matches in iteration 370: [101, 123, 194]
# Matches in iteration 371: [11, 127, 167]
# Matches in iteration 372: [231, 294]
# Matches in iteration 374: [46, 344]
# Matches in iteration 375: [217, 164, 150, 53, 247]
# Matches in iteration 377: [266, 353, 360, 108, 234]
# Matches in iteration 378: [62]
# Matches in iteration 379: [215, 110, 267]
# Matches in iteration 380: [11, 305, 172, 135]
# Matches in iteration 382: [154, 94, 156]
# Matches in iteration 383: [51]
# Matches in iteration 384: [208, 242]
# Matches in iteration 385: [244]
# Matches in iteration 386: [335, 299]
# Matches in iteration 387: [44, 216, 126, 328]
# Matches in iteration 388: [329, 286, 67]
# Matches in iteration 389: [266, 36]
# Matches in iteration 390: [170, 60]
# Matches in iteration 391: [232, 296, 195, 236, 155]
# Matches in iteration 392: [100, 68]
# Matches in iteration 393: [263]
# Matches in iteration 394: [101, 126, 361, 192]
# Matches in iteration 395: [120]
# Matches in iteration 396: [306]
# Matches in iteration 397: [297, 12, 223]
# Matches in iteration 398: [318, 239, 112]
# Matches in iteration 399: [334, 35]
# Matches in iteration 400: [91]
# Matches in iteration 401: [297]
# Matches in iteration 402: [177]
# Matches in iteration 403: [88, 18, 229, 110, 41]
# Matches in iteration 404: [225, 268, 185]
# Matches in iteration 405: [117, 94]
# Matches in iteration 406: [355, 261]
# Matches in iteration 407: [330, 217, 7]
# Matches in iteration 408: [254]
# Matches in iteration 409: [29, 352]
# Matches in iteration 410: [310, 260, 252]
# Matches in iteration 411: [12, 280]
# Matches in iteration 412: [364]
# Matches in iteration 413: [65, 141, 281, 298]
# Matches in iteration 414: [341]
# Matches in iteration 415: [97]
# Matches in iteration 416: [131, 212]
# Matches in iteration 417: [331, 107, 161, 103]
# Matches in iteration 419: [165, 365]
# Matches in iteration 420: [327, 256, 261, 102, 12]
# Matches in iteration 421: [279, 237, 351, 313]
# Matches in iteration 422: [15, 230, 185]
# Matches in iteration 423: [214, 22, 170, 195]
# Matches in iteration 424: [37, 282, 179]
# Matches in iteration 425: [204, 229, 88]
# Matches in iteration 426: [252, 88, 6, 42]
# Matches in iteration 428: [307, 10, 262]
# Matches in iteration 429: [281, 245]
# Matches in iteration 430: [272, 55, 174, 352, 343, 190, 124]
# Matches in iteration 431: [140, 216]
# Matches in iteration 432: [333, 215]
# Matches in iteration 433: [49, 45, 94, 286, 158]
# Matches in iteration 434: [148, 115, 314, 250, 15, 308]
# Matches in iteration 435: [291, 359, 217]
# Matches in iteration 436: [354, 358]
# Matches in iteration 437: [51]
# Matches in iteration 438: [126]
# Matches in iteration 439: [93]
# Matches in iteration 440: [160]
# Matches in iteration 441: [253, 125, 28]
# Matches in iteration 442: [209]
# Matches in iteration 443: [236, 215, 110]
# Matches in iteration 444: [147, 56, 86]
# Matches in iteration 445: [312, 179]
# Matches in iteration 446: [113, 309, 256, 317]
# Matches in iteration 447: [309]
# Matches in iteration 448: [134]
# Matches in iteration 449: [358]
# Matches in iteration 450: [326]
# Matches in iteration 452: [211, 71]
# Matches in iteration 453: [352]
# Matches in iteration 454: [260, 52, 119, 295]
# Matches in iteration 455: [316, 40, 129]
# Matches in iteration 457: [201]
# Matches in iteration 458: [137, 214, 339]
# Matches in iteration 460: [96, 288, 184]
# Matches in iteration 461: [35]
# Matches in iteration 462: [316, 96]
# Matches in iteration 463: [195]
# Matches in iteration 464: [251, 356, 173]
# Matches in iteration 465: [336, 190]
# Matches in iteration 466: [31]
# Matches in iteration 467: [173, 354, 177]
# Matches in iteration 468: [250, 278, 346]
# Matches in iteration 470: [171, 105, 318]
# Matches in iteration 471: [247, 281, 28, 135]
# Matches in iteration 472: [2, 289, 329, 74]
# Matches in iteration 473: [32, 243]
# Matches in iteration 474: [53, 268, 241]
# Matches in iteration 475: [37, 98, 172]
# Matches in iteration 476: [90, 320]
# Matches in iteration 477: [269, 120, 265, 351, 336, 61]
# Matches in iteration 478: [169, 224, 144, 252]
# Matches in iteration 479: [32, 285]
# Matches in iteration 480: [337, 155, 165]
# Matches in iteration 481: [283, 180, 27]
# Matches in iteration 482: [223, 197]
# Matches in iteration 483: [142, 250]
# Matches in iteration 484: [191, 261, 33]
# Matches in iteration 485: [131, 25]
# Matches in iteration 486: [242, 332, 243, 299]
# Matches in iteration 487: [353, 262, 305]
# Matches in iteration 488: [206]
# Matches in iteration 489: [130]
# Matches in iteration 490: [293, 77]
# Matches in iteration 491: [129]
# Matches in iteration 492: [67]
# Matches in iteration 493: [170, 291, 319]
# Matches in iteration 494: [87, 84, 308]
# Matches in iteration 495: [126, 323]
# Matches in iteration 496: [50, 225, 48, 236]
# Matches in iteration 497: [295, 66, 84]
# Matches in iteration 498: [188]
# Matches in iteration 499: [74, 249, 110, 187]
# Matches in iteration 500: [97, 353, 185]
# Matches in iteration 502: [238, 163, 323, 354]
# Matches in iteration 503: [255, 337, 24]
# Matches in iteration 504: [336, 70, 124]
# Matches in iteration 505: [202, 9, 215]
# Matches in iteration 506: [198, 260, 232]
# Matches in iteration 507: [107]
# Matches in iteration 508: [242, 114, 84]
# Matches in iteration 509: [282, 162, 72]
# Matches in iteration 510: [53, 176, 344]
# Matches in iteration 512: [192, 296, 360]
# Matches in iteration 513: [67, 282]
# Matches in iteration 515: [124]
# Matches in iteration 516: [99]
# Matches in iteration 517: [41, 228, 25]
# Matches in iteration 518: [197, 82, 136]
# Matches in iteration 519: [182, 204, 169, 159]
# Matches in iteration 520: [106, 36]
# Matches in iteration 521: [4, 56, 148, 317]
# Matches in iteration 522: [18, 254, 293]
# Matches in iteration 523: [38]
# Matches in iteration 524: [150]
# Matches in iteration 525: [44, 346, 200, 219]
# Matches in iteration 526: [365, 136, 121]
# Matches in iteration 528: [33, 142]
# Matches in iteration 529: [96, 284, 18]
# Matches in iteration 530: [33, 22]
# Matches in iteration 531: [131, 146]
# Matches in iteration 532: [354, 11, 111]
# Matches in iteration 533: [240, 327, 224]
# Matches in iteration 534: [235, 83]
# Matches in iteration 535: [276, 35, 209, 342]
# Matches in iteration 536: [262]
# Matches in iteration 537: [34]
# Matches in iteration 538: [337, 290]
# Matches in iteration 539: [234, 91]
# Matches in iteration 540: [146, 238, 124]
# Matches in iteration 541: [42, 191]
# Matches in iteration 542: [125]
# Matches in iteration 543: [40, 108]
# Matches in iteration 544: [319, 304]
# Matches in iteration 545: [351, 219, 170]
# Matches in iteration 546: [57, 337, 137, 174]
# Matches in iteration 547: [291]
# Matches in iteration 548: [27, 261]
# Matches in iteration 549: [193, 281, 185, 60, 263]
# Matches in iteration 550: [133]
# Matches in iteration 551: [360]
# Matches in iteration 552: [215, 29, 20, 127]
# Matches in iteration 553: [174, 229, 89]
# Matches in iteration 554: [155, 35]
# Matches in iteration 555: [225, 308, 223]
# Matches in iteration 556: [40, 39, 54]
# Matches in iteration 557: [101, 170, 81, 99]
# Matches in iteration 558: [150, 70, 120]
# Matches in iteration 559: [273, 77, 274, 307, 128, 153]
# Matches in iteration 560: [290, 135, 110]
# Matches in iteration 561: [123, 52, 156, 25]
# Matches in iteration 562: [61, 223, 242]
# Matches in iteration 563: [206, 10, 17, 166]
# Matches in iteration 564: [231]
# Matches in iteration 565: [121, 357, 231, 277]
# Matches in iteration 566: [332, 265, 115, 339, 29]
# Matches in iteration 567: [198]
# Matches in iteration 568: [86, 258, 340, 195]
# Matches in iteration 569: [279]
# Matches in iteration 570: [255, 343, 2, 23]
# Matches in iteration 571: [101]
# Matches in iteration 572: [37]
# Matches in iteration 573: [334, 118]
# Matches in iteration 574: [31]
# Matches in iteration 575: [167, 67, 28, 304, 10, 172]
# Matches in iteration 576: [289, 109, 234]
# Matches in iteration 577: [116, 67]
# Matches in iteration 578: [204, 86, 330]
# Matches in iteration 580: [142, 51, 88]
# Matches in iteration 582: [60, 335, 194]
# Matches in iteration 583: [348, 119, 135]
# Matches in iteration 585: [92, 175, 346]
# Matches in iteration 586: [212, 281]
# Matches in iteration 587: [189]
# Matches in iteration 589: [275, 211]
# Matches in iteration 590: [31, 35]
# Matches in iteration 591: [343, 326, 46]
# Matches in iteration 592: [177, 117, 282]
# Matches in iteration 594: [80, 92]
# Matches in iteration 595: [303, 41, 89]
# Matches in iteration 596: [110, 179]
# Matches in iteration 597: [180, 313]
# Matches in iteration 598: [41]
# Matches in iteration 599: [233, 248, 122]
# Matches in iteration 600: [132, 248]
# Matches in iteration 601: [134, 55]
# Matches in iteration 602: [47, 92, 39, 74]
# Matches in iteration 603: [326, 31]
# Matches in iteration 605: [245]
# Matches in iteration 607: [54, 15, 241, 291, 13]
# Matches in iteration 608: [310]
# Matches in iteration 609: [195]
# Matches in iteration 610: [225]
# Matches in iteration 611: [234, 145, 165, 146]
# Matches in iteration 612: [330, 2, 74]
# Matches in iteration 613: [13, 104, 207, 210, 195]
# Matches in iteration 614: [29]
# Matches in iteration 615: [242]
# Matches in iteration 616: [35]
# Matches in iteration 617: [52, 275, 271, 25]
# Matches in iteration 619: [292, 93]
# Matches in iteration 620: [168, 310, 144]
# Matches in iteration 621: [94]
# Matches in iteration 622: [282]
# Matches in iteration 623: [79, 87, 181, 55, 62, 202, 197]
# Matches in iteration 624: [258, 145, 299]
# Matches in iteration 626: [32]
# Matches in iteration 627: [55, 294, 299, 356, 79]
# Matches in iteration 628: [296]
# Matches in iteration 629: [128, 122, 110]
# Matches in iteration 630: [216, 272, 321, 322]
# Matches in iteration 631: [104, 19, 275, 284, 274]
# Matches in iteration 632: [256]
# Matches in iteration 633: [46, 209]
# Matches in iteration 634: [319]
# Matches in iteration 635: [339, 37]
# Matches in iteration 636: [32, 266]
# Matches in iteration 637: [249]
# Matches in iteration 638: [344, 275, 151]
# Matches in iteration 639: [268, 14]
# Matches in iteration 640: [75, 239, 260, 329]
# Matches in iteration 641: [232, 365, 95]
# Matches in iteration 642: [282]
# Matches in iteration 643: [335, 131, 222]
# Matches in iteration 644: [174]
# Matches in iteration 645: [361, 312, 172]
# Matches in iteration 646: [29, 304]
# Matches in iteration 648: [147, 74]
# Matches in iteration 649: [74, 42]
# Matches in iteration 650: [197, 216, 55, 17, 238]
# Matches in iteration 651: [183, 149, 305, 75]
# Matches in iteration 652: [219, 316, 262]
# Matches in iteration 653: [266, 67]
# Matches in iteration 654: [46, 351, 62]
# Matches in iteration 655: [307]
# Matches in iteration 656: [319]
# Matches in iteration 657: [117, 244, 82, 240, 15]
# Matches in iteration 658: [224]
# Matches in iteration 659: [128]
# Matches in iteration 661: [80, 99, 88]
# Matches in iteration 662: [182, 233, 339]
# Matches in iteration 663: [38]
# Matches in iteration 664: [64, 128, 225, 282]
# Matches in iteration 665: [126, 116]
# Matches in iteration 666: [57, 210, 138, 169, 42]
# Matches in iteration 667: [332, 232]
# Matches in iteration 669: [203]
# Matches in iteration 670: [166, 35]
# Matches in iteration 671: [4, 12]
# Matches in iteration 672: [167]
# Matches in iteration 673: [353, 311]
# Matches in iteration 674: [351, 185]
# Matches in iteration 675: [91, 154, 140]
# Matches in iteration 676: [266, 68, 167]
# Matches in iteration 677: [97, 272, 298]
# Matches in iteration 678: [269]
# Matches in iteration 679: [243, 165, 275, 111, 31, 298]
# Matches in iteration 680: [317, 152]
# Matches in iteration 681: [231, 145, 64]
# Matches in iteration 682: [76, 262]
# Matches in iteration 684: [129, 204]
# Matches in iteration 685: [140, 332, 100]
# Matches in iteration 686: [71]
# Matches in iteration 687: [279]
# Matches in iteration 688: [308, 353, 44]
# Matches in iteration 689: [89, 255, 93, 64]
# Matches in iteration 690: [118]
# Matches in iteration 691: [258, 151, 70, 26, 222, 81, 96]
# Matches in iteration 692: [202, 163, 274]
# Matches in iteration 693: [90]
# Matches in iteration 695: [57, 119, 365]
# Matches in iteration 696: [307]
# Matches in iteration 697: [348]
# Matches in iteration 698: [283, 289, 60]
# Matches in iteration 699: [241, 89, 114, 161, 37]
# Matches in iteration 700: [253]
# Matches in iteration 701: [198, 38, 17]
# Matches in iteration 702: [30, 212, 233, 309]
# Matches in iteration 703: [47]
# Matches in iteration 704: [56, 149, 324, 91, 240, 208]
# Matches in iteration 705: [11, 92, 162, 250]
# Matches in iteration 706: [52, 79, 39]
# Matches in iteration 707: [248, 295, 198]
# Matches in iteration 708: [43]
# Matches in iteration 709: [164, 69, 331]
# Matches in iteration 710: [229, 232, 15, 257, 145]
# Matches in iteration 711: [360]
# Matches in iteration 712: [188, 159, 132, 47, 302]
# Matches in iteration 713: [72, 155, 48, 188, 110]
# Matches in iteration 714: [316, 257, 45]
# Matches in iteration 715: [296, 269, 237]
# Matches in iteration 716: [249, 179]
# Matches in iteration 717: [161]
# Matches in iteration 718: [357, 270, 46, 237]
# Matches in iteration 719: [322, 93, 302, 90, 296, 81]
# Matches in iteration 720: [208, 179]
# Matches in iteration 721: [193, 74, 261]
# Matches in iteration 723: [204, 155, 137]
# Matches in iteration 724: [286]
# Matches in iteration 725: [79, 326, 264]
# Matches in iteration 726: [311, 201, 64]
# Matches in iteration 727: [314, 350, 290, 184]
# Matches in iteration 728: [20]
# Matches in iteration 729: [22]
# Matches in iteration 730: [159, 339, 164, 257]
# Matches in iteration 731: [10]
# Matches in iteration 732: [189, 174, 178]
# Matches in iteration 733: [67, 340, 96, 35]
# Matches in iteration 734: [146, 68, 49, 84]
# Matches in iteration 735: [11, 212, 59, 114, 58]
# Matches in iteration 736: [112, 75]
# Matches in iteration 737: [14, 77, 349, 129]
# Matches in iteration 738: [251]
# Matches in iteration 739: [284]
# Matches in iteration 740: [149, 318]
# Matches in iteration 741: [138, 10, 183, 49]
# Matches in iteration 742: [253, 361, 318]
# Matches in iteration 743: [94, 288]
# Matches in iteration 744: [123, 178, 272, 317]
# Matches in iteration 745: [115, 361]
# Matches in iteration 746: [171, 22, 330]
# Matches in iteration 747: [217, 303, 149]
# Matches in iteration 748: [90, 297, 2]
# Matches in iteration 749: [358, 33, 186]
# Matches in iteration 750: [365, 30, 53, 69]
# Matches in iteration 751: [263, 205, 72]
# Matches in iteration 752: [80, 218]
# Matches in iteration 753: [340]
# Matches in iteration 754: [288, 16, 242, 19]
# Matches in iteration 755: [137, 119, 107]
# Matches in iteration 756: [104, 116, 195]
# Matches in iteration 757: [323, 158, 120, 118]
# Matches in iteration 758: [97, 39, 255, 213]
# Matches in iteration 759: [315]
# Matches in iteration 760: [56]
# Matches in iteration 761: [282, 348]
# Matches in iteration 762: [130, 8, 161, 29, 167]
# Matches in iteration 763: [62, 329, 296, 65]
# Matches in iteration 764: [206, 158]
# Matches in iteration 765: [257, 74, 193, 190]
# Matches in iteration 766: [51, 114]
# Matches in iteration 767: [63, 278, 14]
# Matches in iteration 768: [277, 46, 92, 93, 124, 119]
# Matches in iteration 769: [48, 311, 275, 191, 20]
# Matches in iteration 770: [89, 96, 112, 218]
# Matches in iteration 771: [78]
# Matches in iteration 772: [256, 191, 39]
# Matches in iteration 773: [204]
# Matches in iteration 774: [149]
# Matches in iteration 775: [202, 128, 343]
# Matches in iteration 776: [309, 267, 73, 317]
# Matches in iteration 777: [64, 322, 73, 151, 345, 300]
# Matches in iteration 778: [274, 197, 4, 242]
# Matches in iteration 779: [58, 85, 154]
# Matches in iteration 780: [126]
# Matches in iteration 781: [249, 216]
# Matches in iteration 782: [314]
# Matches in iteration 783: [159, 263, 340]
# Matches in iteration 784: [76]
# Matches in iteration 785: [26, 250, 303, 133, 12]
# Matches in iteration 786: [128, 199, 177, 248]
# Matches in iteration 787: [25]
# Matches in iteration 788: [81]
# Matches in iteration 789: [306, 259]
# Matches in iteration 790: [294]
# Matches in iteration 791: [20, 317, 50, 183, 361, 149]
# Matches in iteration 792: [335, 302, 232]
# Matches in iteration 793: [305, 210, 199, 240]
# Matches in iteration 795: [300, 141, 276]
# Matches in iteration 796: [329, 99, 17]
# Matches in iteration 797: [355, 260]
# Matches in iteration 798: [229]
# Matches in iteration 799: [256, 113]
# Matches in iteration 800: [271, 1]
# Matches in iteration 801: [65, 302, 78]
# Matches in iteration 802: [109]
# Matches in iteration 803: [310, 213, 187]
# Matches in iteration 805: [320, 196]
# Matches in iteration 806: [213, 97, 259, 286]
# Matches in iteration 807: [344]
# Matches in iteration 808: [179, 157, 235]
# Matches in iteration 810: [6]
# Matches in iteration 811: [8]
# Matches in iteration 812: [245]
# Matches in iteration 813: [77]
# Matches in iteration 814: [273, 134, 294]
# Matches in iteration 815: [52, 123, 73]
# Matches in iteration 816: [154, 349, 331, 19]
# Matches in iteration 817: [212, 249, 210]
# Matches in iteration 818: [120]
# Matches in iteration 819: [39, 155]
# Matches in iteration 820: [47, 148, 273]
# Matches in iteration 821: [240]
# Matches in iteration 822: [183, 129]
# Matches in iteration 823: [102, 58, 121]
# Matches in iteration 825: [186, 222, 127, 211]
# Matches in iteration 826: [41, 84, 276]
# Matches in iteration 827: [227, 284]
# Matches in iteration 828: [130, 225, 186]
# Matches in iteration 829: [112, 165]
# Matches in iteration 830: [305, 47]
# Matches in iteration 831: [241, 314]
# Matches in iteration 832: [326, 51]
# Matches in iteration 833: [232]
# Matches in iteration 834: [202, 107]
# Matches in iteration 835: [268, 249]
# Matches in iteration 836: [166, 105, 298, 55]
# Matches in iteration 837: [293, 176]
# Matches in iteration 838: [342, 88]
# Matches in iteration 840: [216, 125, 223]
# Matches in iteration 842: [13]
# Matches in iteration 843: [327, 172, 168, 69]
# Matches in iteration 844: [158, 326, 48, 309]
# Matches in iteration 845: [304]
# Matches in iteration 846: [251, 363, 153]
# Matches in iteration 847: [350]
# Matches in iteration 848: [188, 58]
# Matches in iteration 849: [124]
# Matches in iteration 850: [133, 142, 199]
# Matches in iteration 851: [127]
# Matches in iteration 854: [6, 355, 42, 306]
# Matches in iteration 855: [8, 70, 261]
# Matches in iteration 856: [89, 151, 31]
# Matches in iteration 857: [97]
# Matches in iteration 858: [105, 194]
# Matches in iteration 859: [291, 5]
# Matches in iteration 861: [300, 39]
# Matches in iteration 862: [186, 120, 316, 261, 95]
# Matches in iteration 863: [142, 156, 36, 67]
# Matches in iteration 864: [7]
# Matches in iteration 865: [9, 232, 99]
# Matches in iteration 866: [232, 58, 127]
# Matches in iteration 867: [75, 85]
# Matches in iteration 868: [358, 306, 58]
# Matches in iteration 869: [350, 260, 252, 58]
# Matches in iteration 870: [288]
# Matches in iteration 871: [248]
# Matches in iteration 872: [182, 251]
# Matches in iteration 873: [326, 76, 358, 73, 153]
# Matches in iteration 874: [330, 209]
# Matches in iteration 875: [205]
# Matches in iteration 876: [40, 313]
# Matches in iteration 877: [1, 239]
# Matches in iteration 878: [45, 256]
# Matches in iteration 879: [215, 43]
# Matches in iteration 880: [91, 313, 146]
# Matches in iteration 881: [223]
# Matches in iteration 882: [199, 317]
# Matches in iteration 883: [302, 365, 286, 345, 43]
# Matches in iteration 884: [335, 218]
# Matches in iteration 885: [60, 111]
# Matches in iteration 886: [192, 120, 359]
# Matches in iteration 887: [126, 275, 21, 45, 9]
# Matches in iteration 888: [198, 188]
# Matches in iteration 889: [256, 269, 340, 184]
# Matches in iteration 890: [200, 266, 240, 65, 293, 21]
# Matches in iteration 891: [198, 247, 199, 315]
# Matches in iteration 892: [37, 175, 92, 309, 341]
# Matches in iteration 893: [251, 123, 224]
# Matches in iteration 894: [34, 131, 12, 216]
# Matches in iteration 895: [214, 18]
# Matches in iteration 896: [333, 234, 151]
# Matches in iteration 897: [16, 364]
# Matches in iteration 898: [87, 156, 235]
# Matches in iteration 899: [2, 92]
# Matches in iteration 900: [8, 133, 257]
# Matches in iteration 901: [297, 335, 127]
# Matches in iteration 902: [325, 216, 309]
# Matches in iteration 903: [228]
# Matches in iteration 904: [19]
# Matches in iteration 905: [107, 6, 74, 105]
# Matches in iteration 906: [321, 351, 228]
# Matches in iteration 907: [124, 13]
# Matches in iteration 908: [142]
# Matches in iteration 909: [212]
# Matches in iteration 910: [119, 211]
# Matches in iteration 911: [37, 138, 286]
# Matches in iteration 912: [342]
# Matches in iteration 913: [31, 246]
# Matches in iteration 914: [132]
# Matches in iteration 915: [125, 202, 298]
# Matches in iteration 916: [354, 346, 304, 28]
# Matches in iteration 917: [256, 70, 95, 270]
# Matches in iteration 918: [81, 235, 286]
# Matches in iteration 919: [199, 12, 175]
# Matches in iteration 920: [117]
# Matches in iteration 921: [281, 297, 311]
# Matches in iteration 922: [338, 243, 166]
# Matches in iteration 923: [311, 302, 141]
# Matches in iteration 924: [362, 53, 196, 295, 284, 37]
# Matches in iteration 925: [152, 9, 211]
# Matches in iteration 926: [273, 168, 360]
# Matches in iteration 927: [323]
# Matches in iteration 928: [343, 190, 186]
# Matches in iteration 929: [218, 256, 344, 292]
# Matches in iteration 930: [219, 106]
# Matches in iteration 931: [100, 340, 293, 295]
# Matches in iteration 932: [318]
# Matches in iteration 933: [136, 196, 225]
# Matches in iteration 935: [4, 286]
# Matches in iteration 936: [285, 142, 226]
# Matches in iteration 938: [351, 298]
# Matches in iteration 939: [233, 104]
# Matches in iteration 940: [295]
# Matches in iteration 941: [174]
# Matches in iteration 942: [257, 173, 351]
# Matches in iteration 944: [283, 124, 74]
# Matches in iteration 945: [114, 105, 195, 172, 123]
# Matches in iteration 946: [51, 96]
# Matches in iteration 947: [247, 277]
# Matches in iteration 948: [211, 59, 360]
# Matches in iteration 949: [271]
# Matches in iteration 950: [150, 10, 81, 215]
# Matches in iteration 951: [336, 349, 324]
# Matches in iteration 952: [80]
# Matches in iteration 953: [199, 231, 356, 160, 193]
# Matches in iteration 955: [293, 36, 354]
# Matches in iteration 956: [361, 56]
# Matches in iteration 957: [116, 180]
# Matches in iteration 958: [273, 165]
# Matches in iteration 959: [252, 134]
# Matches in iteration 960: [316]
# Matches in iteration 961: [36, 126]
# Matches in iteration 962: [261, 207, 357, 115]
# Matches in iteration 963: [321, 181]
# Matches in iteration 964: [355]
# Matches in iteration 965: [352, 235, 32, 3, 355]
# Matches in iteration 966: [43]
# Matches in iteration 967: [254]
# Matches in iteration 968: [138, 255]
# Matches in iteration 969: [249, 174, 106, 70]
# Matches in iteration 970: [320]
# Matches in iteration 971: [350, 209, 178]
# Matches in iteration 972: [11, 356, 305, 234]
# Matches in iteration 973: [277]
# Matches in iteration 974: [294, 166, 211]
# Matches in iteration 975: [151, 129, 33]
# Matches in iteration 976: [255, 54]
# Matches in iteration 977: [20, 179]
# Matches in iteration 978: [275, 145]
# Matches in iteration 979: [110, 302, 94, 96]
# Matches in iteration 980: [188]
# Matches in iteration 981: [315, 99]
# Matches in iteration 982: [18, 186]
# Matches in iteration 983: [70, 27]
# Matches in iteration 984: [284]
# Matches in iteration 985: [150, 198]
# Matches in iteration 986: [86, 208]
# Matches in iteration 988: [123, 236, 12, 132, 257, 36]
# Matches in iteration 989: [63, 29]
# Matches in iteration 990: [353]
# Matches in iteration 991: [22, 253]
# Matches in iteration 992: [204]
# Matches in iteration 993: [90]
# Matches in iteration 994: [245, 254, 159, 237]
# Matches in iteration 995: [323, 294, 56, 195, 216]
# Matches in iteration 996: [342, 189]
# Matches in iteration 997: [212, 119]
# Matches in iteration 998: [217, 362]
# Matches in iteration 999: [81, 309, 325]
# Matches in iteration 1000: [224, 324, 338]
# Matches in iteration 1001: [250, 81, 245, 46, 275, 325]
# Matches in iteration 1002: [118]
# Matches in iteration 1003: [127, 138]
# Matches in iteration 1004: [244, 246, 57, 35, 32]
# Matches in iteration 1005: [212, 361, 252, 209]
# Matches in iteration 1006: [243, 186, 175]
# Matches in iteration 1007: [241, 134]
# Matches in iteration 1008: [55, 242, 81]
# Matches in iteration 1009: [241]
# Matches in iteration 1010: [88, 159, 77]
# Matches in iteration 1011: [32, 50]
# Matches in iteration 1012: [309]
# Matches in iteration 1013: [44, 240]
# Matches in iteration 1014: [152]
# Matches in iteration 1015: [316, 57, 71]
# Matches in iteration 1016: [310, 336, 172]
# Matches in iteration 1017: [183, 320, 328]
# Matches in iteration 1018: [157, 14, 344]
# Matches in iteration 1019: [125, 72]
# Matches in iteration 1020: [72]
# Matches in iteration 1021: [21, 178, 222, 2, 268]
# Matches in iteration 1022: [193, 165]
# Matches in iteration 1023: [90, 319]
# Matches in iteration 1024: [227, 310, 239, 143]
# Matches in iteration 1025: [97, 268, 330, 27, 351, 331]
# Matches in iteration 1027: [350, 362, 256, 365]
# Matches in iteration 1028: [200, 34]
# Matches in iteration 1029: [153, 209, 248]
# Matches in iteration 1030: [5]
# Matches in iteration 1031: [11]
# Matches in iteration 1032: [89, 105, 341, 200]
# Matches in iteration 1033: [8, 268, 83, 349]
# Matches in iteration 1034: [43, 287, 116]
# Matches in iteration 1035: [272]
# Matches in iteration 1037: [212]
# Matches in iteration 1038: [315, 27, 127, 362]
# Matches in iteration 1039: [16, 330, 110]
# Matches in iteration 1040: [342, 73]
# Matches in iteration 1041: [301]
# Matches in iteration 1042: [118, 253, 159, 155, 14, 34]
# Matches in iteration 1043: [345]
# Matches in iteration 1044: [299, 286, 202, 353, 273]
# Matches in iteration 1045: [182, 61, 232]
# Matches in iteration 1046: [188, 64]
# Matches in iteration 1047: [47, 172, 116]
# Matches in iteration 1049: [86, 23, 58, 278]
# Matches in iteration 1050: [156]
# Matches in iteration 1051: [13, 153, 138]
# Matches in iteration 1052: [349, 46, 164]
# Matches in iteration 1053: [197, 317, 69, 53, 264, 50]
# Matches in iteration 1054: [235, 136, 119, 81]
# Matches in iteration 1055: [216, 363, 237]
# Matches in iteration 1056: [261, 241]
# Matches in iteration 1057: [243, 55, 340]
# Matches in iteration 1058: [177, 1, 6]
# Matches in iteration 1059: [135, 315]
# Matches in iteration 1060: [43]
# Matches in iteration 1061: [248]
# Matches in iteration 1062: [318]
# Matches in iteration 1063: [243, 128]
# Matches in iteration 1064: [55, 147, 87, 262]
# Matches in iteration 1065: [348, 246, 76]
# Matches in iteration 1066: [29, 248, 93]
# Matches in iteration 1067: [128, 50, 228, 108]
# Matches in iteration 1068: [328, 247, 17]
# Matches in iteration 1069: [213]
# Matches in iteration 1070: [95, 207, 214]
# Matches in iteration 1071: [174, 158]
# Matches in iteration 1072: [204]
# Matches in iteration 1073: [10, 234, 153, 14]
# Matches in iteration 1074: [329, 98]
# Matches in iteration 1075: [189, 116]
# Matches in iteration 1076: [6, 49, 267]
# Matches in iteration 1077: [124]
# Matches in iteration 1078: [209, 199, 56, 343]
# Matches in iteration 1079: [84, 251, 359, 108]
# Matches in iteration 1080: [357]
# Matches in iteration 1081: [17, 32]
# Matches in iteration 1082: [73, 85, 67]
# Matches in iteration 1083: [139]
# Matches in iteration 1084: [35, 25, 149]
# Matches in iteration 1085: [232]
# Matches in iteration 1086: [111, 108]
# Matches in iteration 1087: [113, 73]
# Matches in iteration 1088: [63, 348, 332]
# Matches in iteration 1089: [68, 60, 153]
# Matches in iteration 1090: [322, 132, 116, 114, 227]
# Matches in iteration 1091: [94]
# Matches in iteration 1093: [243]
# Matches in iteration 1094: [279]
# Matches in iteration 1095: [178]
# Matches in iteration 1096: [93]
# Matches in iteration 1097: [237, 187, 42]
# Matches in iteration 1098: [197, 71, 186]
# Matches in iteration 1100: [357, 26]
# Matches in iteration 1101: [145]
# Matches in iteration 1102: [4, 234]
# Matches in iteration 1103: [52, 203, 359, 28]
# Matches in iteration 1104: [135, 25, 98]
# Matches in iteration 1105: [61, 138, 278, 15]
# Matches in iteration 1106: [352]
# Matches in iteration 1107: [324, 181]
# Matches in iteration 1108: [200, 249, 181]
# Matches in iteration 1109: [66, 281, 61]
# Matches in iteration 1111: [58, 184, 185]
# Matches in iteration 1112: [221, 318, 344, 350, 28]
# Matches in iteration 1113: [134, 323, 105]
# Matches in iteration 1114: [95, 164, 47, 159, 22]
# Matches in iteration 1115: [39]
# Matches in iteration 1116: [150]
# Matches in iteration 1117: [191, 333, 248]
# Matches in iteration 1118: [7]
# Matches in iteration 1119: [280, 287, 110]
# Matches in iteration 1120: [264, 11]
# Matches in iteration 1121: [62, 287, 231, 170]
# Matches in iteration 1122: [323, 342]
# Matches in iteration 1123: [88, 291, 92]
# Matches in iteration 1124: [361, 81, 168, 162]
# Matches in iteration 1125: [186, 32]
# Matches in iteration 1126: [77, 90, 308, 87, 165]
# Matches in iteration 1127: [197]
# Matches in iteration 1128: [310, 284]
# Matches in iteration 1129: [359]
# Matches in iteration 1130: [261, 246, 8, 22]
# Matches in iteration 1133: [19, 106]
# Matches in iteration 1134: [93, 310, 268]
# Matches in iteration 1135: [66, 204, 330]
# Matches in iteration 1136: [288, 128, 154]
# Matches in iteration 1137: [49, 61]
# Matches in iteration 1139: [359, 337, 218]
# Matches in iteration 1140: [237, 29, 140]
# Matches in iteration 1141: [58, 40, 250]
# Matches in iteration 1142: [195, 132, 91, 77]
# Matches in iteration 1143: [153, 67, 7]
# Matches in iteration 1144: [41, 212]
# Matches in iteration 1145: [271, 331]
# Matches in iteration 1146: [296, 303, 174, 191]
# Matches in iteration 1147: [207, 147, 295, 240]
# Matches in iteration 1148: [49, 101, 146, 99, 204]
# Matches in iteration 1149: [106, 363, 275, 326, 192, 2]
# Matches in iteration 1150: [36]
# Matches in iteration 1151: [251, 273, 198]
# Matches in iteration 1153: [280, 254]
# Matches in iteration 1154: [321, 143]
# Matches in iteration 1155: [250]
# Matches in iteration 1156: [255, 342]
# Matches in iteration 1157: [113, 54, 251]
# Matches in iteration 1158: [291, 131]
# Matches in iteration 1159: [352, 26, 283]
# Matches in iteration 1161: [334, 206]
# Matches in iteration 1162: [329]
# Matches in iteration 1163: [335]
# Matches in iteration 1164: [117, 158]
# Matches in iteration 1165: [263, 252, 158]
# Matches in iteration 1167: [130, 227]
# Matches in iteration 1168: [237, 277]
# Matches in iteration 1169: [134, 73, 11, 210, 162, 357]
# Matches in iteration 1170: [138]
# Matches in iteration 1171: [82, 313]
# Matches in iteration 1172: [209, 318]
# Matches in iteration 1173: [264, 44, 158, 184]
# Matches in iteration 1174: [75]
# Matches in iteration 1176: [252, 122, 336]
# Matches in iteration 1177: [214, 325, 92, 332]
# Matches in iteration 1178: [230, 121, 276, 63]
# Matches in iteration 1179: [102]
# Matches in iteration 1180: [130]
# Matches in iteration 1181: [272, 179]
# Matches in iteration 1182: [312, 264, 281, 49]
# Matches in iteration 1184: [222, 331]
# Matches in iteration 1186: [245, 312, 103, 139]
# Matches in iteration 1187: [215]
# Matches in iteration 1188: [254, 363, 89]
# Matches in iteration 1189: [97, 277, 138]
# Matches in iteration 1190: [308, 8, 274, 101]
# Matches in iteration 1191: [182]
# Matches in iteration 1192: [365, 242, 60]
# Matches in iteration 1193: [137, 248]
# Matches in iteration 1194: [1, 316, 166, 310]
# Matches in iteration 1195: [21]
# Matches in iteration 1196: [269, 90, 165]
# Matches in iteration 1197: [96, 99, 145, 329, 63, 8]
# Matches in iteration 1198: [6, 177, 119]
# Matches in iteration 1199: [148, 283, 229, 249, 325]
# Matches in iteration 1200: [311]
# Matches in iteration 1201: [129, 146]
# Matches in iteration 1202: [247, 59]
# Matches in iteration 1203: [171, 43, 289]
# Matches in iteration 1204: [140]
# Matches in iteration 1205: [363, 355, 198]
# Matches in iteration 1206: [326, 132, 292]
# Matches in iteration 1207: [266, 323]
# Matches in iteration 1208: [146, 152]
# Matches in iteration 1209: [44, 92]
# Matches in iteration 1211: [87, 172, 327]
# Matches in iteration 1212: [47]
# Matches in iteration 1213: [348, 294]
# Matches in iteration 1214: [243, 6]
# Matches in iteration 1215: [217, 22, 17]
# Matches in iteration 1216: [41, 349, 129, 137]
# Matches in iteration 1217: [199, 63]
# Matches in iteration 1218: [266]
# Matches in iteration 1220: [49, 64]
# Matches in iteration 1221: [90, 206, 8]
# Matches in iteration 1222: [113, 265, 339]
# Matches in iteration 1223: [59, 101]
# Matches in iteration 1224: [23, 258]
# Matches in iteration 1225: [38, 268, 317]
# Matches in iteration 1226: [235, 344, 20, 11, 16]
# Matches in iteration 1227: [145]
# Matches in iteration 1228: [216, 333, 289, 131]
# Matches in iteration 1229: [267]
# Matches in iteration 1231: [76, 350]
# Matches in iteration 1232: [363, 318, 327]
# Matches in iteration 1233: [249]
# Matches in iteration 1234: [130, 324]
# Matches in iteration 1235: [260, 207]
# Matches in iteration 1236: [156, 56]
# Matches in iteration 1237: [343, 73]
# Matches in iteration 1238: [173, 266, 319]
# Matches in iteration 1239: [201, 95]
# Matches in iteration 1241: [99, 174, 257]
# Matches in iteration 1242: [2, 103]
# Matches in iteration 1243: [53, 40, 203, 70]
# Matches in iteration 1244: [231, 50]
# Matches in iteration 1245: [163]
# Matches in iteration 1246: [38, 180, 73]
# Matches in iteration 1247: [103, 337, 75]
# Matches in iteration 1248: [173, 297, 9, 132]
# Matches in iteration 1249: [162, 281]
# Matches in iteration 1250: [3]
# Matches in iteration 1251: [135, 37]
# Matches in iteration 1252: [224, 329, 65]
# Matches in iteration 1253: [264]
# Matches in iteration 1254: [318, 163]
# Matches in iteration 1255: [319, 243]
# Matches in iteration 1256: [261, 104, 290]
# Matches in iteration 1257: [337, 88, 93, 329]
# Matches in iteration 1258: [212]
# Matches in iteration 1259: [180, 238, 150, 355]
# Matches in iteration 1260: [120, 284]
# Matches in iteration 1262: [302, 169]
# Matches in iteration 1263: [213, 237]
# Matches in iteration 1264: [294]
# Matches in iteration 1266: [156, 268]
# Matches in iteration 1267: [94, 21, 170]
# Matches in iteration 1268: [311, 143, 267]
# Matches in iteration 1269: [160, 306, 266, 316, 264]
# Matches in iteration 1270: [363, 85, 137]
# Matches in iteration 1271: [77, 261, 166, 71, 18, 257]
# Matches in iteration 1272: [207, 76, 51, 298]
# Matches in iteration 1273: [112]
# Matches in iteration 1274: [111, 321, 151, 7]
# Matches in iteration 1275: [133, 180]
# Matches in iteration 1276: [63, 331, 25, 157]
# Matches in iteration 1278: [153, 272, 74]
# Matches in iteration 1279: [360, 182, 82, 124]
# Matches in iteration 1280: [65, 94, 138]
# Matches in iteration 1281: [115]
# Matches in iteration 1282: [71, 205]
# Matches in iteration 1284: [227, 23]
# Matches in iteration 1285: [362, 334, 254, 236]
# Matches in iteration 1286: [48, 39, 271]
# Matches in iteration 1287: [244, 334, 146]
# Matches in iteration 1288: [79, 261, 160]
# Matches in iteration 1289: [303, 168, 202, 24]
# Matches in iteration 1290: [108, 316, 25]
# Matches in iteration 1291: [16, 114, 69]
# Matches in iteration 1292: [327]
# Matches in iteration 1293: [231, 328, 84]
# Matches in iteration 1294: [53, 197]
# Matches in iteration 1295: [143, 358, 60, 169]
# Matches in iteration 1296: [34, 184]
# Matches in iteration 1297: [156, 189, 125, 68]
# Matches in iteration 1298: [128, 289, 325, 332]
# ...
# Matches in iteration 4097: [189]
# Matches in iteration 4098: [11]
# Matches in iteration 4100: [5, 152, 284]
# Matches in iteration 4101: [327]
# Matches in iteration 4102: [235, 71]
# Matches in iteration 4104: [193, 206, 105]
# Matches in iteration 4105: [104, 229, 54]
# Matches in iteration 4106: [33, 185]
# Matches in iteration 4107: [145, 138, 363]
# Matches in iteration 4108: [230, 21]
# Matches in iteration 4109: [269, 321]
# Matches in iteration 4110: [282]
# Matches in iteration 4111: [61, 211, 230, 277, 39, 31]
# Matches in iteration 4112: [362, 10]
# Matches in iteration 4113: [22, 29, 85]
# Matches in iteration 4114: [90, 7]
# Matches in iteration 4115: [180, 188, 277]
# Matches in iteration 4116: [11]
# Matches in iteration 4117: [149, 30]
# Matches in iteration 4118: [215, 134]
# Matches in iteration 4119: [337, 325]
# Matches in iteration 4120: [265]
# Matches in iteration 4121: [117]
# Matches in iteration 4122: [33, 21, 313, 8, 35]
# Matches in iteration 4123: [342]
# Matches in iteration 4124: [14, 119]
# Matches in iteration 4125: [103, 94, 133, 181]
# Matches in iteration 4126: [177, 283, 286, 197, 358, 301]
# Matches in iteration 4128: [145]
# Matches in iteration 4129: [76, 304, 145]
# Matches in iteration 4130: [277]
# Matches in iteration 4131: [365, 66]
# Matches in iteration 4132: [93, 161, 250, 217]
# Matches in iteration 4133: [210]
# Matches in iteration 4134: [321, 40, 2]
# Matches in iteration 4135: [230, 159, 343]
# Matches in iteration 4136: [35, 256, 18]
# Matches in iteration 4137: [199, 315]
# Matches in iteration 4138: [188, 141, 307]
# Matches in iteration 4139: [220]
# Matches in iteration 4140: [292]
# Matches in iteration 4141: [144, 1, 97]
# Matches in iteration 4142: [152, 193, 279, 19]
# Matches in iteration 4143: [204, 227, 188, 138, 360]
# Matches in iteration 4144: [234, 309, 162]
# Matches in iteration 4145: [337, 219, 68, 226]
# Matches in iteration 4146: [243, 286, 13]
# Matches in iteration 4147: [38, 212, 270]
# Matches in iteration 4148: [301]
# Matches in iteration 4149: [221, 48]
# Matches in iteration 4150: [261, 173]
# Matches in iteration 4151: [46, 309, 331]
# Matches in iteration 4152: [335, 207]
# Matches in iteration 4153: [362, 241]
# Matches in iteration 4154: [36, 65]
# Matches in iteration 4155: [152, 148, 191]
# Matches in iteration 4156: [341, 198]
# Matches in iteration 4157: [49, 144]
# Matches in iteration 4158: [311]
# Matches in iteration 4159: [44, 337, 327, 70]
# Matches in iteration 4160: [297, 229, 50, 74]
# Matches in iteration 4161: [56, 89]
# Matches in iteration 4162: [58, 183, 246, 115]
# Matches in iteration 4163: [205, 320, 337]
# Matches in iteration 4164: [243, 214, 11]
# Matches in iteration 4165: [61, 106, 143, 176, 12, 39]
# Matches in iteration 4166: [253, 343]
# Matches in iteration 4167: [136, 60, 204]
# Matches in iteration 4168: [68]
# Matches in iteration 4169: [78, 7, 212]
# Matches in iteration 4170: [321]
# Matches in iteration 4171: [309, 53, 59, 151, 132, 163, 351]
# Matches in iteration 4172: [207, 289, 55]
# Matches in iteration 4173: [149, 135, 203]
# Matches in iteration 4174: [77, 241]
# Matches in iteration 4175: [253, 42, 54, 303, 86]
# Matches in iteration 4176: [52, 286, 271]
# Matches in iteration 4177: [158, 266, 79, 360, 88]
# Matches in iteration 4178: [269, 316, 53, 297]
# Matches in iteration 4179: [25, 70]
# Matches in iteration 4180: [222, 154, 163]
# Matches in iteration 4181: [151, 221, 21]
# Matches in iteration 4182: [7, 274, 233, 115, 138]
# Matches in iteration 4183: [73]
# Matches in iteration 4184: [222]
# Matches in iteration 4185: [192, 143, 161, 358, 235, 77, 295, 296]
# Matches in iteration 4186: [33, 36]
# Matches in iteration 4187: [23]
# Matches in iteration 4188: [106, 126, 357]
# Matches in iteration 4189: [188, 239, 74, 113]
# Matches in iteration 4190: [96, 47, 126]
# Matches in iteration 4191: [71, 297, 226, 330, 355]
# Matches in iteration 4192: [243, 339, 254, 309, 180]
# Matches in iteration 4193: [212, 7]
# Matches in iteration 4194: [12, 249]
# Matches in iteration 4195: [138, 327, 306, 339]
# Matches in iteration 4196: [40, 185]
# Matches in iteration 4198: [124, 170, 175, 10]
# Matches in iteration 4199: [273]
# Matches in iteration 4200: [115, 318]
# Matches in iteration 4201: [148]
# Matches in iteration 4202: [306]
# Matches in iteration 4203: [247, 254, 287, 281]
# Matches in iteration 4204: [223]
# Matches in iteration 4205: [119, 1, 139]
# Matches in iteration 4206: [209]
# Matches in iteration 4207: [27, 131]
# Matches in iteration 4208: [146, 360, 155, 98]
# Matches in iteration 4210: [293]
# Matches in iteration 4211: [148, 92]
# Matches in iteration 4212: [289, 112]
# Matches in iteration 4213: [277, 267]
# Matches in iteration 4214: [272]
# Matches in iteration 4215: [69]
# Matches in iteration 4216: [20, 343, 364, 288]
# Matches in iteration 4217: [241]
# Matches in iteration 4218: [173, 106, 125, 356]
# Matches in iteration 4219: [251, 359, 293, 268]
# Matches in iteration 4220: [95, 211, 262, 310, 319]
# Matches in iteration 4221: [25, 207, 289]
# Matches in iteration 4222: [185, 252, 70, 330]
# Matches in iteration 4223: [45, 225, 109]
# Matches in iteration 4224: [134, 330]
# Matches in iteration 4225: [40, 247, 102]
# Matches in iteration 4226: [121, 65, 15]
# Matches in iteration 4227: [227, 141]
# Matches in iteration 4228: [334, 317, 92]
# Matches in iteration 4229: [338, 225]
# Matches in iteration 4230: [11, 159, 21, 278, 187]
# Matches in iteration 4231: [244, 144, 102, 162]
# Matches in iteration 4232: [94, 136, 155]
# Matches in iteration 4233: [326, 153, 53, 345, 175, 209]
# Matches in iteration 4234: [136, 94, 157, 34, 93]
# Matches in iteration 4235: [347, 43]
# Matches in iteration 4236: [337, 48, 195]
# Matches in iteration 4237: [43, 191]
# Matches in iteration 4238: [253, 302]
# Matches in iteration 4239: [100]
# Matches in iteration 4240: [67, 188]
# Matches in iteration 4241: [191, 225, 220]
# Matches in iteration 4242: [102]
# Matches in iteration 4243: [131, 350, 58, 29, 205]
# Matches in iteration 4244: [266]
# Matches in iteration 4245: [103, 325, 177]
# Matches in iteration 4246: [365, 168, 320, 158]
# Matches in iteration 4247: [145, 65, 166]
# Matches in iteration 4248: [271, 244]
# Matches in iteration 4250: [242]
# Matches in iteration 4251: [204, 181, 140]
# Matches in iteration 4252: [147, 212, 125, 335]
# Matches in iteration 4253: [247, 146]
# Matches in iteration 4254: [131, 221, 322]
# Matches in iteration 4255: [249, 71, 84, 271, 208, 111]
# Matches in iteration 4256: [206, 78, 364]
# Matches in iteration 4257: [26, 296, 82]
# Matches in iteration 4258: [134, 193, 285, 128, 1]
# Matches in iteration 4259: [257]
# Matches in iteration 4260: [182, 19, 163, 231]
# Matches in iteration 4261: [356, 18, 178, 234]
# Matches in iteration 4263: [98, 323, 341]
# Matches in iteration 4264: [210]
# Matches in iteration 4265: [219, 351]
# Matches in iteration 4266: [171, 236]
# Matches in iteration 4267: [132, 201]
# Matches in iteration 4268: [100, 110]
# Matches in iteration 4269: [104, 213]
# Matches in iteration 4270: [211, 94]
# Matches in iteration 4271: [111, 22, 189]
# Matches in iteration 4273: [268, 291, 205, 249]
# Matches in iteration 4274: [55, 223, 246, 313, 203]
# Matches in iteration 4275: [153, 83, 151, 21]
# Matches in iteration 4276: [320, 64, 360, 264, 172, 26]
# Matches in iteration 4277: [57, 278]
# Matches in iteration 4278: [218]
# Matches in iteration 4279: [281, 299, 272, 26]
# Matches in iteration 4280: [312]
# Matches in iteration 4281: [256, 332, 60, 145]
# Matches in iteration 4282: [263, 48, 42, 227]
# Matches in iteration 4283: [5, 211, 229, 271, 257]
# Matches in iteration 4284: [297]
# Matches in iteration 4285: [117, 354, 321, 317, 311, 279]
# Matches in iteration 4287: [108]
# Matches in iteration 4288: [274, 58]
# Matches in iteration 4289: [153, 95]
# Matches in iteration 4290: [250]
# Matches in iteration 4291: [270, 152, 76, 137, 61]
# Matches in iteration 4292: [146, 173]
# Matches in iteration 4293: [2, 12, 309]
# Matches in iteration 4294: [251]
# Matches in iteration 4295: [128, 60]
# Matches in iteration 4296: [191, 359, 326]
# Matches in iteration 4297: [137, 58]
# Matches in iteration 4298: [190, 31, 263, 159, 173, 303]
# Matches in iteration 4299: [75, 89, 298, 238, 348, 217]
# Matches in iteration 4300: [216]
# Matches in iteration 4301: [338, 289, 89]
# Matches in iteration 4302: [238, 125, 129, 172, 73]
# Matches in iteration 4303: [261, 118, 338]
# Matches in iteration 4304: [220]
# Matches in iteration 4305: [312, 56]
# Matches in iteration 4306: [25, 2]
# Matches in iteration 4307: [231, 135, 272, 180]
# Matches in iteration 4308: [333, 127, 45]
# Matches in iteration 4309: [323, 150]
# Matches in iteration 4310: [3, 291, 83]
# Matches in iteration 4311: [23, 163, 323, 16]
# Matches in iteration 4312: [215, 158, 92]
# Matches in iteration 4313: [2]
# Matches in iteration 4314: [163, 222, 176]
# Matches in iteration 4315: [55, 47]
# Matches in iteration 4316: [199, 216, 365]
# Matches in iteration 4317: [61, 29, 155]
# Matches in iteration 4318: [28, 249, 343]
# Matches in iteration 4319: [188, 204]
# Matches in iteration 4320: [337, 40, 211]
# Matches in iteration 4321: [150, 82, 47]
# Matches in iteration 4322: [160, 360]
# Matches in iteration 4323: [348, 207, 266, 164, 1]
# Matches in iteration 4324: [323]
# Matches in iteration 4325: [154, 2, 306]
# Matches in iteration 4326: [53, 150, 149, 103]
# Matches in iteration 4327: [66, 85]
# Matches in iteration 4328: [98, 341]
# Matches in iteration 4329: [279]
# Matches in iteration 4330: [311, 193]
# Matches in iteration 4331: [126, 99, 17, 92]
# Matches in iteration 4332: [8, 60, 262, 93, 286, 128]
# Matches in iteration 4333: [56, 48, 218, 344]
# Matches in iteration 4334: [280, 72, 151, 322, 275]
# Matches in iteration 4335: [59, 286, 81, 209]
# Matches in iteration 4336: [168]
# Matches in iteration 4337: [28, 80, 132]
# Matches in iteration 4338: [278]
# Matches in iteration 4339: [39, 299]
# Matches in iteration 4340: [285, 6, 277, 37]
# Matches in iteration 4342: [247, 54, 169]
# Matches in iteration 4343: [211, 162]
# Matches in iteration 4344: [40, 80, 183, 289, 157]
# Matches in iteration 4346: [120, 266]
# Matches in iteration 4347: [107, 50]
# Matches in iteration 4348: [171, 241, 297, 41, 233, 169]
# Matches in iteration 4349: [216, 132, 114]
# Matches in iteration 4350: [72, 307, 162, 239]
# Matches in iteration 4351: [292, 18, 297]
# Matches in iteration 4352: [169, 284, 335]
# Matches in iteration 4353: [335, 187, 40]
# Matches in iteration 4354: [208, 80, 50]
# Matches in iteration 4355: [142, 108, 234]
# Matches in iteration 4356: [322, 62, 182]
# Matches in iteration 4358: [308, 110]
# Matches in iteration 4359: [310]
# Matches in iteration 4360: [168, 234, 181, 261]
# Matches in iteration 4361: [79]
# Matches in iteration 4362: [354, 319]
# Matches in iteration 4363: [250, 93, 303]
# Matches in iteration 4364: [15]
# Matches in iteration 4365: [358, 203]
# Matches in iteration 4366: [265, 297, 355]
# Matches in iteration 4367: [280]
# Matches in iteration 4368: [188, 253]
# Matches in iteration 4369: [197, 318, 117, 352]
# Matches in iteration 4370: [359, 332, 358]
# Matches in iteration 4371: [164, 96]
# Matches in iteration 4372: [226, 135]
# Matches in iteration 4373: [190]
# Matches in iteration 4374: [276, 309]
# Matches in iteration 4375: [110, 14, 294, 44, 342, 330]
# Matches in iteration 4376: [153, 57]
# Matches in iteration 4377: [144, 121, 299]
# Matches in iteration 4378: [301, 70]
# Matches in iteration 4379: [346]
# Matches in iteration 4380: [261, 354]
# Matches in iteration 4381: [279, 127, 67, 5, 123, 252]
# Matches in iteration 4382: [35, 188, 55, 229]
# Matches in iteration 4383: [103, 41, 260]
# Matches in iteration 4384: [220]
# Matches in iteration 4385: [329]
# Matches in iteration 4387: [110]
# Matches in iteration 4388: [154, 180, 147]
# Matches in iteration 4389: [44, 365]
# Matches in iteration 4390: [307, 60]
# Matches in iteration 4391: [123, 340]
# Matches in iteration 4392: [151]
# Matches in iteration 4393: [143, 116, 184]
# Matches in iteration 4394: [34, 124, 114, 87]
# Matches in iteration 4395: [185]
# Matches in iteration 4396: [133, 348, 159]
# Matches in iteration 4397: [158, 126, 163]
# Matches in iteration 4398: [39, 129, 318, 207]
# Matches in iteration 4399: [91]
# Matches in iteration 4400: [5, 269, 77, 126, 197, 99]
# Matches in iteration 4401: [272]
# Matches in iteration 4402: [62, 142, 249, 193, 331]
# Matches in iteration 4403: [21, 191, 128, 144]
# Matches in iteration 4404: [267]
# Matches in iteration 4405: [283, 176]
# Matches in iteration 4406: [102, 340]
# Matches in iteration 4407: [38]
# Matches in iteration 4408: [299, 102]
# Matches in iteration 4409: [56, 321, 219]
# Matches in iteration 4410: [103, 126, 151]
# Matches in iteration 4411: [86, 33, 67]
# Matches in iteration 4412: [305, 260, 65, 80]
# Matches in iteration 4413: [274, 276, 216, 17]
# Matches in iteration 4414: [293, 30, 133]
# Matches in iteration 4415: [212, 357]
# Matches in iteration 4416: [127, 139, 239, 38]
# Matches in iteration 4417: [100, 292, 351]
# Matches in iteration 4418: [184, 239]
# Matches in iteration 4419: [354, 67, 111, 349, 204, 317]
# Matches in iteration 4420: [40, 311, 125, 341, 328, 43]
# Matches in iteration 4421: [203, 286, 189, 334, 168, 68]
# Matches in iteration 4422: [87, 278, 361]
# Matches in iteration 4423: [135, 114, 17, 247]
# Matches in iteration 4424: [108, 147, 239, 4]
# Matches in iteration 4425: [8, 314]
# Matches in iteration 4426: [322, 170]
# Matches in iteration 4427: [221, 188]
# Matches in iteration 4428: [356, 197, 150]
# Matches in iteration 4429: [339, 344, 99]
# Matches in iteration 4430: [122, 109, 132]
# Matches in iteration 4431: [89, 30, 297, 11]
# Matches in iteration 4432: [47, 214, 40, 105]
# Matches in iteration 4433: [294, 196]
# Matches in iteration 4434: [241, 188, 343, 277, 247]
# Matches in iteration 4435: [47]
# Matches in iteration 4436: [230, 137, 298]
# Matches in iteration 4437: [111, 44, 255]
# Matches in iteration 4438: [116, 266, 250]
# Matches in iteration 4439: [255, 242]
# Matches in iteration 4440: [146, 39, 364, 89, 168]
# Matches in iteration 4441: [301, 194, 272]
# Matches in iteration 4442: [354, 320, 257]
# Matches in iteration 4443: [80, 97]
# Matches in iteration 4445: [321, 64]
# Matches in iteration 4446: [183, 146, 103]
# Matches in iteration 4447: [360, 263, 177]
# Matches in iteration 4448: [2, 325, 196]
# Matches in iteration 4449: [9, 75, 119]
# Matches in iteration 4450: [261, 135, 143]
# Matches in iteration 4451: [251]
# Matches in iteration 4452: [194, 30, 126, 233]
# Matches in iteration 4454: [246, 206]
# Matches in iteration 4455: [125, 119, 168]
# Matches in iteration 4456: [76, 265]
# Matches in iteration 4457: [118, 310, 206, 174]
# Matches in iteration 4458: [244]
# Matches in iteration 4459: [254, 87, 81, 96, 1]
# Matches in iteration 4460: [128, 112, 62]
# Matches in iteration 4461: [257, 336, 207, 124, 159, 140]
# Matches in iteration 4462: [319, 357, 188, 4]
# Matches in iteration 4463: [103, 212]
# Matches in iteration 4464: [277, 160, 121, 334]
# Matches in iteration 4465: [154, 292, 360, 291]
# Matches in iteration 4466: [13, 224]
# Matches in iteration 4467: [308, 330]
# Matches in iteration 4468: [6]
# Matches in iteration 4469: [270, 235]
# Matches in iteration 4470: [129, 235, 66, 329]
# Matches in iteration 4471: [33, 14]
# Matches in iteration 4472: [42]
# Matches in iteration 4473: [241]
# Matches in iteration 4474: [364, 252, 248, 335, 327]
# Matches in iteration 4475: [192]
# Matches in iteration 4476: [171]
# Matches in iteration 4477: [355, 346]
# Matches in iteration 4478: [212, 345, 309, 20]
# Matches in iteration 4479: [127, 286, 267, 303, 3]
# Matches in iteration 4480: [41, 178, 195]
# Matches in iteration 4481: [342, 208]
# Matches in iteration 4483: [339]
# Matches in iteration 4484: [148, 138, 86, 133, 48]
# Matches in iteration 4485: [258]
# Matches in iteration 4486: [47, 95]
# Matches in iteration 4487: [351, 179, 341, 190]
# Matches in iteration 4488: [212]
# Matches in iteration 4489: [292, 209]
# Matches in iteration 4490: [219, 350, 99]
# Matches in iteration 4491: [210, 229, 299, 346]
# Matches in iteration 4492: [86, 353, 254]
# Matches in iteration 4493: [184, 206, 16]
# Matches in iteration 4494: [190, 238, 269]
# Matches in iteration 4495: [228]
# Matches in iteration 4496: [25, 159]
# Matches in iteration 4497: [102, 258, 344, 238]
# Matches in iteration 4498: [330, 310, 315, 120]
# Matches in iteration 4499: [166, 213]
# Matches in iteration 4500: [337, 181, 204, 75]
